# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/spaces',
#  '/models',
#  '/nanonets/Nanonets-OCR-s',
#  '/MiniMaxAI/MiniMax-M1-80k',
#  '/Menlo/Jan-nano',
#  '/google/magenta-realtime',
#  '/moonshotai/Kimi-Dev-72B',
#  '/models',
#  '/spaces/ilcve21/Sparc3D',
#  '/spaces/enzostvs/deepsite',
#  '/spaces/tencent/Hunyuan3D-2.1',
#  '/spaces/MiniMaxAI/MiniMax-M1',
#  '/spaces/nvidia/PartPacker',
#  '/spaces',
#  '/datasets/EssentialAI/essential-web-v1.0',
#  '/datasets/institutional/institutional-books-1.0',
#  '/datasets/fka/awesome-chatgpt-prompts',
#  '/datasets/nvidia/AceReason-1.1-SFT',
#  '/datasets/nvidia/Nemotron-Personas',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/changelog',
#  'https://endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/'},
#   {'type': 'company page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'community page', 'url': 'https://discuss.huggingface.co'},
#   {'type': 'GitHub page', 'url': 'https://github.com/huggingface'},
#   {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'},
#   {'type': 'LinkedIn page',
#    'url': 'https://www.linkedin.com/company/huggingface/'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'company page', 'url': 'https://discuss.huggingface.co'}, {'type': 'social media (LinkedIn)', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'social media (Twitter)', 'url': 'https://twitter.com/huggingface'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# nanonets/Nanonets-OCR-s
# Updated
# 3 days ago
# •
# 177k
# •
# 1.07k
# MiniMaxAI/MiniMax-M1-80k
# Updated
# 5 days ago
# •
# 10.4k
# •
# 523
# Menlo/Jan-nano
# Updated
# 6 days ago
# •
# 29.1k
# •
# 372
# google/magenta-realtime
# Updated
# about 15 hours ago
# •
# 225
# moonshotai/Kimi-Dev-72B
# Updated
# 7 days ago
# •
# 9.72k
# •
# 260
# Browse 1M+ models
# Spaces
# Running
# 714
# 714
# Sparc3D
# 🏃
# Next-Gen High-Resolution 3D Model Generation
# Running
# 8.51k
# 8.51k
# DeepSite v2
# 🐳
# Generate any application with DeepSeek
# Running
# on
# Zero
# 411
# 411
# Hunyuan3D-2.1
# 👻
# Image-to-3D Generation
# Running
# 251
# 251
# MiniMax M1
# 💬
# Generate code from text prompts
# Running
# on
# Zero
# 194
# 194
# PartPacker
# 🪴
# Part-level image-to-3D generation.
# Browse 400k+ applications
# Datasets
# EssentialAI/essential-web-v1.0
# Updated
# 1 day ago
# •
# 75.5k
# •
# 137
# institutional/institutional-books-1.0
# Updated
# 7 days ago
# •
# 38.2k
# •
# 164
# fka/awesome-chatgpt-prompts
# Updated
# Jan 6
# •
# 22.9k
# •
# 8.01k
# nvidia/AceReason-1.1-SFT
# Updated
# 5 days ago
# •
# 2.95k
# •
# 32
# nvidia/Nemotron-Personas
# Updated
# 14 days ago
# •
# 18.5k
# •
# 142
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 766 models
# •
# 3.48k followers
# AI at Meta
# Enterprise
# company
# •
# 2.17k models
# •
# 6.57k followers
# Amazon
# company
# •
# 20 models
# •
# 3.25k followers
# Google
# company
# •
# 1k models
# •
# 17.2k followers
# Intel
# company
# •
# 234 models
# •
# 2.66k followers
# Microsoft
# company
# •
# 393 models
# •
# 13.1k followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 165 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 298 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 145,980
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 29,458
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,319
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,707
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,828
# Fast tokenizers optimized for research & production
# TRL
# 14,301
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,877
# State-of-the-art ML running directly in your browser
# smolagents
# 20,475
# Smol library to build great agents in Python
# PEFT
# 18,837
# Parameter-efficient finetuning for large language models
# Datasets
# 20,290
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,246
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,865
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
# Zhihu
# WeChat
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 45,024
# AI & ML interests
# The AI community building the future.
# Recent Activity
# lysandre
# updated
# a dataset
# about 10 hours ago
# huggingface/transformers-metadata
# cyrilzakka
# authored
# a paper
# 13 days ago
# MammoGANesis: Controlled Generation of High-Resolution Mammograms for
#   Radiology Education
# cyrilzakka
# authored
# a paper
# 13 days ago
# A Generalizable Deep Learning System for Cardiac MRI
# View all activity
# Articles
# Yay! Organizations can now publish blog Articles
# Jan 20
# •
# 46
# Team members
# 213
# +179
# +166
# +145
# +135
# +115
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 248k
# •
# •
# 50
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 8.8M
# •
# •
# 712
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 1.07M
# •
# 198
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# Updated
# Dec 19, 2023
# •
# 4.33M
# •
# •
# 786
# spaces
# 29
# Sort:
# 		Recently updated
# pinned
# Running
# 13
# Enterprise Hub
# 🔒
# Why you need it, how to get it
# huggingface
# 10 days ago
# pinned
# Running
# on
# CPU Upgrade
# 11
# Hugging Face Fast
# 🏎
# Test your internet connection speed
# huggingface
# 11 days ago
# pinned
# Running
# 93
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# 183
# Inference Playground
# 🔋
# Toggle dark/light theme on Hugging Face Playground
# huggingface
# 5 days ago
# Running
# on
# CPU Upgrade
# 12
# Openapi
# 🦀
# Hub API Documentation
# huggingface
# 5 days ago
# Running
# 435
# AI Deadlines
# ⚡
# Organize project deadlines with AI assistance
# huggingface
# 16 days ago
# View 29
# 							Spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/time-series-transformer-tourism-monthly
# Time Series Forecasting
# •
# Updated
# about 1 month ago
# •
# 4.37k
# •
# 22
# huggingface/timesfm-tourism-monthly
# Updated
# Mar 31
# •
# 23
# •
# 2
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 51.5k
# •
# •
# 62
# huggingface/falcon-40b-gptq
# Text Generation
# •
# Updated
# Jun 14, 2023
# •
# 38
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 52.9k
# •
# 9
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# Updated
# Mar 22, 2023
# •
# 362
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 52.8k
# •
# 6
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 23
# •
# 5
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 124k
# •
# •
# 81
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 1
# View 16
# 							models
# datasets
# 34
# Sort:
# 		Recently updated
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# about 10 hours ago
# •
# 1.69k
# •
# 2.14k
# •
# 25
# huggingface/documentation-images
# Viewer
# •
# Updated
# 3 days ago
# •
# 52
# •
# 3M
# •
# 69
# huggingface/cats-image
# Viewer
# •
# Updated
# 4 days ago
# •
# 1
# •
# 9.88k
# •
# 2
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# 10 days ago
# •
# 70
# •
# 544
# •
# 7
# huggingface/label-files
# Updated
# 11 days ago
# •
# 2.09k
# •
# 18
# huggingface/policy-docs
# Viewer
# •
# Updated
# 20 days ago
# •
# 24
# •
# 2.31k
# •
# 11
# huggingface/electricity-production
# Viewer
# •
# Updated
# May 22
# •
# 397
# •
# 124
# •
# 1
# huggingface/badges
# Viewer
# •
# Updated
# Apr 8
# •
# 1
# •
# 1.39M
# •
# 45
# huggingface/gemini-results-new-cs-papers-2025-02-11-100-230-updated
# Viewer
# •
# Updated
# Feb 17
# •
# 130
# •
# 252
# huggingface/wiki_dpr
# Updated
# Feb 5
# •
# 335
# View 34
# 							datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# enterprise page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Team & Enterprise Hub
# Scale your organization with the world’s leading AI platform
# Subscribe to
# Team
# starting at $20/user/month
# or
# Contact sales for
# Enterprise
# to explore flexible contract options
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU.
# ZeroGPU Quota Boost
# All organization members get 5x more ZeroGPU quota to get the most of Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Private Storage
# Get an additional 1 TB of private storage for each member of your organization (then $25/month per extra TB).
# Inference Providers
# Enable organization billing for Inference Providers, monitor usage with analytics, and manage spending limits.
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Team
# starting at $20/user/month
# or
# Contact sales for
# Enterprise
# to explore flexible contract options
# NVIDIA
# Enterprise
# company
# •
# 413 models
# •
# 29.8k followers
# AI at Meta
# Enterprise
# company
# •
# 2.17k models
# •
# 6.57k followers
# Snowflake
# Enterprise
# company
# •
# 23 models
# •
# 548 followers
# Arm
# Enterprise
# company
# •
# 218 followers
# Qwen
# Enterprise
# company
# •
# 321 models
# •
# 36k followers
# Xsolla
# Enterprise
# company
# •
# 141 followers
# Nutanix
# Enterprise
# company
# •
# 261 models
# •
# 111 followers
# Jusbrasil
# Enterprise
# company
# •
# 98 followers
# creditkarma
# Enterprise
# company
# •
# 71 followers
# HyperCLOVA X
# Enterprise
# company
# •
# 3 models
# •
# 363 followers
# MiniMax
# Enterprise
# company
# •
# 7 models
# •
# 1.28k followers
# Liquid AI
# Enterprise
# company
# •
# 208 followers
# Novo Nordisk R&ED
# Enterprise
# company
# •
# 37 followers
# Adyen
# Enterprise
# company
# •
# 68 followers
# Meta Llama
# Enterprise
# company
# •
# 70 models
# •
# 49.3k followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 303 followers
# Orange
# Enterprise
# company
# •
# 7 models
# •
# 241 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 298 followers
# ServiceNow
# Enterprise
# company
# •
# 514 followers
# ServiceNow-AI
# Enterprise
# company
# •
# 3 models
# •
# 288 followers
# Fidelity Investments
# Enterprise
# company
# •
# 151 followers
# TNG Technology Consulting GmbH
# Enterprise
# company
# •
# 4 models
# •
# 158 followers
# Technology Innovation Institute
# Enterprise
# company
# •
# 101 models
# •
# 1.46k followers
# Chegg Inc
# Enterprise
# company
# •
# 87 followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 165 followers
# Lightricks
# Enterprise
# company
# •
# 13 models
# •
# 1.08k followers
# Stability AI
# Enterprise
# company
# •
# 108 models
# •
# 25.6k followers
# BAIDU
# Enterprise
# company
# •
# 337 followers
# Shopify
# Enterprise
# company
# •
# 481 followers
# AMD
# Enterprise
# company
# •
# 145 models
# •
# 1.62k followers
# JetBrains
# Enterprise
# company
# •
# 10 models
# •
# 578 followers
# Together
# Enterprise
# company
# •
# 33 models
# •
# 627 followers
# LiveRAG by AIIR
# Enterprise
# company
# •
# 130 followers
# Toyota Research Institute
# Enterprise
# company
# •
# 10 models
# •
# 123 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 154 followers
# IBM Granite
# Enterprise
# company
# •
# 125 models
# •
# 1.93k followers
# H2O.ai
# Enterprise
# company
# •
# 71 models
# •
# 430 followers
# HiddenLayer
# Enterprise
# company
# •
# 1 model
# •
# 74 followers
# LinkedIn
# Enterprise
# company
# •
# 63 followers
# BCG X
# Enterprise
# company
# •
# 40 followers
# Twelve Labs
# Enterprise
# company
# •
# 48 followers
# Widn AI
# Enterprise
# company
# •
# 48 followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# Inference Providers
# Transformers backend integration in SGLang
# By
# marcsun13
# June 23, 2025
# •
# 12
# Community Articles
# view all
# 🤔👀🎬🖥️ Kimi-VL-A3B-Thinking-2506: A Quick Navigation
# By
# moonshotai
# and 1 other
# •
# 2 days ago
# •
# 36
# Fine-tune Llama 3.1 Ultra-Efficiently with Unsloth
# By
# mlabonne
# •
# Jul 29, 2024
# •
# 341
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 101
# Mastering Tensor Dimensions in Transformers
# By
# not-lain
# •
# Jan 12
# •
# 69
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 159
# Saying Thank You to a LLM Isn't Free — Measuring the Energy Cost of Politeness
# By
# jdelavande
# and 2 others
# •
# 12 days ago
# •
# 16
# 💥 Building a Vulnerable Bank MCP — Then Automating an Agent to Hack It
# By
# jdelavande
# and 2 others
# •
# 5 days ago
# •
# 7
# Adaptive Classifier: Dynamic Text Classification with Continuous Learning
# By
# codelion
# •
# 3 days ago
# •
# 7
# Introducing Cosmos Predict-2: A Foundation For Your Own World Model
# By
# nvidia
# and 2 others
# •
# 7 days ago
# •
# 6
# Whose Voice Do We Hear When AI Speaks?
# By
# giadap
# •
# 4 days ago
# •
# 6
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 614
# The Large Language Model Course
# By
# mlabonne
# •
# Jan 16
# •
# 193
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 83
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 295
# DO THEY SEE WHAT WE SEE?
# By
# felfri
# •
# 1 day ago
# •
# 5
# Post-Training Isaac GR00T N1.5 for LeRobot SO-101 Arm
# By
# nvidia
# and 4 others
# •
# 12 days ago
# •
# 61
# Why Maybe We're Measuring LLM Compression Wrong
# By
# rishiraj
# •
# 2 days ago
# •
# 4
# Real-Time AI Sound Generation on Arm: A Personal Tool for Creative Freedom
# By
# Arm
# and 1 other
# •
# 20 days ago
# •
# 6
# Sensitivity Aware Mixed Precision Quantization V1
# By
# badaoui
# and 1 other
# •
# 10 days ago
# •
# 13
# Supercharge Edge AI with High Accuracy Reasoning Using Llama Nemotron Nano 4B
# By
# nvidia
# and 3 others
# •
# 13 days ago
# •
# 6
# (LoRA) Fine-Tuning FLUX.1-dev on Consumer Hardware
# By
# derekl35
# June 19, 2025
# •
# 56
# Groq on Hugging Face Inference Providers 🔥
# By
# sbrandeis
# June 16, 2025
# •
# 31
# Enhance Your Models in 5 Minutes with the Hugging Face Kernel Hub
# By
# drbh
# June 12, 2025
# •
# 96
# Featherless AI on Hugging Face Inference Providers 🔥
# By
# sbrandeis
# June 12, 2025
# •
# 40
# Introducing Training Cluster as a Service - a new collaboration with NVIDIA
# By
# jeffboudier
# June 11, 2025
# •
# 22
# ScreenSuite - The most comprehensive evaluation suite for GUI Agents!
# By
# a-mahla
# June 6, 2025
# •
# 47
# KV Cache from scratch in nanoVLM
# By
# ariG23498
# June 4, 2025
# •
# 76
# SmolVLA: Efficient Vision-Language-Action Model trained on Lerobot Community Data
# By
# danaaubakirova
# June 3, 2025
# •
# 158
# No GPU left behind: Unlocking Efficiency with Co-located vLLM in TRL
# By
# toslali-ibm
# June 3, 2025
# guest
# •
# 56
# CodeAgents + Structure: A Better Way to Execute Actions
# By
# akseljoonas
# May 28, 2025
# •
# 59
# 🐯 Liger GRPO meets TRL
# By
# shisahni
# May 25, 2025
# guest
# •
# 43
# Dell Enterprise Hub is all you need to build AI on premises
# By
# jeffboudier
# May 23, 2025
# •
# 19
# Tiny Agents in Python: a MCP-powered agent in ~70 lines of code
# By
# celinah
# May 23, 2025
# •
# 134
# Exploring Quantization Backends in Diffusers
# By
# derekl35
# May 21, 2025
# •
# 36
# Previous
# 1
# 2
# 3
# ...
# 42
# Next
# Community Articles
# Sort:
# 		Trending
# 🤔👀🎬🖥️ Kimi-VL-A3B-Thinking-2506: A Quick Navigation
# By
# moonshotai
# and 1 other
# •
# 2 days ago
# •
# 36
# Fine-tune Llama 3.1 Ultra-Efficiently with Unsloth
# By
# mlabonne
# •
# Jul 29, 2024
# •
# 341
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 101
# Mastering Tensor Dimensions in Transformers
# By
# not-lain
# •
# Jan 12
# •
# 69
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 159
# Saying Thank You to a LLM Isn't Free — Measuring the Energy Cost of Politeness
# By
# jdelavande
# and 2 others
# •
# 12 days ago
# •
# 16
# 💥 Building a Vulnerable Bank MCP — Then Automating an Agent to Hack It
# By
# jdelavande
# and 2 others
# •
# 5 days ago
# •
# 7
# Adaptive Classifier: Dynamic Text Classification with Continuous Learning
# By
# codelion
# •
# 3 days ago
# •
# 7
# Introducing Cosmos Predict-2: A Foundation For Your Own World Model
# By
# nvidia
# and 2 others
# •
# 7 days ago
# •
# 6
# Whose Voice Do We Hear When AI Speaks?
# By
# giadap
# •
# 4 days ago
# •
# 6
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 614
# The Large Language Model Course
# By
# mlabonne
# •
# Jan 16
# •
# 193
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 83
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 295
# DO THEY SEE WHAT WE SEE?
# By
# felfri
# •
# 1 day ago
# •
# 5
# Post-Training Isaac GR00T N1.5 for LeRobot SO-101 Arm
# By
# nvidia
# and 4 others
# •
# 12 days ago
# •
# 61
# Why Maybe We're Measuring LLM Compression Wrong
# By
# rishiraj
# •
# 2 days ago
# •
# 4
# Real-Time AI Sound Generation on Arm: A Personal Tool for Creative Freedom
# By
# Arm
# and 1 other
# •
# 20 days ago
# •
# 6
# Sensitivity Aware Mixed Precision Quantization V1
# By
# badaoui
# and 1 other
# •
# 10 days ago
# •
# 13
# Supercharge Edge AI with High Accuracy Reasoning Using Llama Nemotron Nano 4B
# By
# nvidia
# and 3 others
# •
# 13 days ago
# •
# 6
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# company page
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# Account Issue: Persistent 401 Unauthorized Error on All Downloads
# 🤗Hub
# 3
# 14
# June 23, 2025
# Looking for a BI/Analytics AI component/engine
# Intermediate
# 1
# 9
# June 23, 2025
# Prakash Hinduja Switzerland (Swiss) Can I use Hugging Face models for real-time inference on edge devices?
# Beginners
# 1
# 13
# June 23, 2025
# Clarification on Dataset Size Discrepancy – Common Pile v0.1
# 🤗Datasets
# 1
# 7
# June 23, 2025
# Artificial intelligence
# Beginners
# 2
# 31
# June 22, 2025
# Seeking feedback on my intuitive understanding of backpropagation from from (from Rumelhart et al., 1986's paper)
# Research
# 2
# 11
# June 22, 2025
# How to decode CSM tokens into audio tensors for streaming
# 🤗Transformers
# 1
# 7
# June 23, 2025
# Getting errors while running google Collab's code  attached to chapter 3
# Beginners
# 2
# 7
# June 23, 2025
# 404 Page Not Found when accessing the "Multiple Choice Quiz" in the "Exam Time!" section of the LLM Course (Section 11: Fine-Tune Large Language Models)
# Course
# 7
# 41
# June 23, 2025
# 502 Bad Gateway when accessing Hugging Face Chat
# Beginners
# 1
# 13
# June 23, 2025
# Wanted to know how to increase the storage limit in git lfs which is set to 1 GB
# Spaces
# 2
# 9
# June 23, 2025
# GPT-4 API Failing with “Connection error” on Paid CPU and Free tier CPU — Worked 2 Days Ago
# Spaces
# 1
# 20
# June 23, 2025
# Prevent iterable dataset from consuming all the rams
# Beginners
# 1
# 9
# June 23, 2025
# AI Interior Design Web App
# Beginners
# 7
# 24
# June 23, 2025
# Visualize attention maps of ViT
# Models
# 1
# 14
# June 22, 2025
# Built a new plot that can visualize 5–7 dimensions in 3D without losing interpretability — introducing Multi-Dimensional Radial Plot (MDRV)
# Research
# 20
# 88
# June 20, 2025
# Make your LLM think differently - Multi Dimensional Reasoning Prompts
# Research
# 12
# 104
# June 21, 2025
# Should we distinguish between context shifts and true hallucinations in LLM outputs?
# Research
# 0
# 14
# June 21, 2025
# Can someone with a Chinese Baidu NetDisk account help me download this dataset?
# 🤗Datasets
# 0
# 8
# June 22, 2025
# _js Gradio error
# Beginners
# 2
# 17
# June 21, 2025
# Using ONNX format of the facebook/mbart-large-50-many-to-many-mmt?
# Intermediate
# 2
# 38
# June 23, 2025
# Strange problem with huggingface-cli
# 🤗Hub
# 18
# 46
# June 23, 2025
# Creating a HF Dataset from lakeFS with S3 storage takes too much time!
# 🤗Datasets
# 6
# 41
# June 23, 2025
# An example of using Strong Attractors to boost LLM analogical thinking
# Intermediate
# 0
# 15
# June 22, 2025
# Can VHD Files Be Used as a Vector DB?
# Research
# 2
# 14
# June 23, 2025
# Does attention_mask refer to input_ids or to labels?
# Beginners
# 7
# 26
# June 19, 2025
# RSOS: Emergent Symbolic Recursion in GPT-4
# Research
# 7
# 219
# June 19, 2025
# Model does not exist while running chat-ui through docker
# Beginners
# 1
# 9
# June 22, 2025
# Finetune Stable Diffusion with depth controlnet on interior datasets
# 🧨 Diffusers
# 1
# 7
# June 22, 2025
# Errors with label2id/id2label with muticlass classification
# Beginners
# 1
# 7
# June 22, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# social media (LinkedIn)
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# View all 563 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# Terrence Rohan
# Seed Investor
# See all employees
# Updates
# Hugging Face
# reposted this
# Gradio
# 66,185 followers
# 6h
# Edited
# Report this post
# 🍃
# Mistral AI
# Choice Award of $2000 worth of API Credits goes to OpenSorus!🤯
#
# This GitHub agent automates issue triage for open-source projects. It reads GitHub issues, analyzes codebases using semantic search, and posts contextually relevant responses - like having a 24/7 developer support assistant.
#
# Built with
# Gradio
# and
# Mistral AI
# 's Devstral & Codestral models. Perfect solution for overwhelmed OSS maintainers! 💪
#
# $2000 API credits well deserved 🏆 Check out the agentic app here:
# https://lnkd.in/gfKeRt7W
# 33
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 66,185 followers
# 8h
# Edited
# Report this post
# 🚀 LLAMAINDEX CHOICE AWARD 🦙 Cash Prize: $1,000 💰
# NASA Space Explorer wins
# LlamaIndex
# 's choice award at the
# Gradio
# Agents & MCP hackathon!
#
# 🌌What they built: LlamaIndex-powered Agentic app that delivers NASA's live space data via custom MCP servers with 15 specialized NASA tools
#
# 📣
# NASA - National Aeronautics and Space Administration
# - Space Explorer
# 🥳 Play with the winning app here:
# https://lnkd.in/gEJeB2vX
# 🙌 🩵 Thanks to the brilliant LLamaIndex team of
# Tuana Çelik
# ,
# Logan Markewich
# , and
# Laurie Voss
# , for making this collaboration a HUGE success!
# 33
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Merve Noyan
# open-sourceress at 🤗
# 1d
# Edited
# Report this post
# fav open-source multimodal reasoning model just got an update 🔥
# Kimi-VL-A3B-Thinking-2506 is
# > smarter with less tokens, small size (only 3B active params!!!)
# > more accurate
# > does video reasoning
# > handles higher resolution 🤯
# https://lnkd.in/dNvcgeDn
# Try the demo here
# https://lnkd.in/dmU57Xxw
# 248
# 6 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Derek Liu
# ML Engineer @ Hugging Face
# 4d
# Report this post
# Now you can make Flux.1 your own within just 10GBs of VRAM. In our new blog post we walk you through the process step by step.
# Check it out here:
# https://lnkd.in/dCY4w8MR
# You can finetune + do inference with FLUX.1-dev for free on a Google Colab T4 GPU.
# google colab:
# https://lnkd.in/duFaGNQY
# The magic behind this is QLoRA.
# QLoRA enables efficient fine-tuning by tackling the two main sources of VRAM usage:
#
# Low-Rank Adaptation (LoRA): We freeze the large base model and inject small, trainable "adapter" matrices into its layers. Only these adapters are trained, reducing trainable parameters by >99%. This reduces the VRAM required for storing gradients and optimizer states (e.g., for Adam).
# Quantization (the "Q"): The frozen, multi-billion parameter base model is loaded using a quantized 4-bit data type. This dramatically reduces the memory footprint for storing the model's weights, making it feasible to fit much larger models into VRAM.
#
# But QLoRA isn't the only trick. We combined several optimizations to stay under 10GB:
# - 8-bit Adam Optimizer: Slashes optimizer memory by ~75%.
# - Gradient Checkpointing: Trades a bit of compute for huge memory savings.
# - Cached Latents & Embeddings: Pre-compute VAE and Text Encoder outputs so they're never in VRAM during training.
#
# Together with QLoRA these three tricks keep the whole fine-tune under 10 GB on a T4 or similar.
#
# More tips & code in the full blog post 👉
# https://lnkd.in/dCY4w8MR
# 364
# 9 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Derek Liu
# ML Engineer @ Hugging Face
# 4d
# Report this post
# Now you can make Flux.1 your own within just 10GBs of VRAM. In our new blog post we walk you through the process step by step.
# Check it out here:
# https://lnkd.in/dCY4w8MR
# You can finetune + do inference with FLUX.1-dev for free on a Google Colab T4 GPU.
# google colab:
# https://lnkd.in/duFaGNQY
# The magic behind this is QLoRA.
# QLoRA enables efficient fine-tuning by tackling the two main sources of VRAM usage:
#
# Low-Rank Adaptation (LoRA): We freeze the large base model and inject small, trainable "adapter" matrices into its layers. Only these adapters are trained, reducing trainable parameters by >99%. This reduces the VRAM required for storing gradients and optimizer states (e.g., for Adam).
# Quantization (the "Q"): The frozen, multi-billion parameter base model is loaded using a quantized 4-bit data type. This dramatically reduces the memory footprint for storing the model's weights, making it feasible to fit much larger models into VRAM.
#
# But QLoRA isn't the only trick. We combined several optimizations to stay under 10GB:
# - 8-bit Adam Optimizer: Slashes optimizer memory by ~75%.
# - Gradient Checkpointing: Trades a bit of compute for huge memory savings.
# - Cached Latents & Embeddings: Pre-compute VAE and Text Encoder outputs so they're never in VRAM during training.
#
# Together with QLoRA these three tricks keep the whole fine-tune under 10 GB on a T4 or similar.
#
# More tips & code in the full blog post 👉
# https://lnkd.in/dCY4w8MR
# 364
# 9 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Merve Noyan
# open-sourceress at 🤗
# 5d
# Report this post
# So many interesting models released past week in open AI! 🤖
#
# 🖼️ Computer Vision/VLMs
# > Nanonets-OCR-s is the new state-of-the-art OCR model that can handle checkboxes, watermarks, tables (OS)
# > Meta released V-JEPA, new sota video embeddings with two new classification models (OS)
# > SeedVR2-3B is a new 3B video restoration model by ByteDance (OS)
#
# 🗣️ Audio
# > Stepfun released Step-Audio-AQAA, new large (137B 🤯) audio language model that takes in audio and generates audio (OS)
#
# 🤖 Robotics
# > nvidia released GR00T-N1.5-3B, new open foundation vision language action model
#
# 3D
# > Hunyuan3D-2.1 is the new version of Hunyuan by Tencent that can generate 3D assets from text and image prompts
#
# Which one peeked your interest? 👀
# …more
# 497
# 10 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning @ 🤗 Hugging Face
# 5d
# Report this post
# New Chapter in the LLM Course! If you’re upskilling on fine-tuning AI, you should join this FREE and CERTIFIED course now:
#
# 🔗
# https://lnkd.in/epgEBujr
# We’ve revised and rebooted Chapter 3 of the LLM Course on fine-tuning language models so now it includes:
#
# - an introduction to the Hugging Face ecosystem of python libraries, including transformers, datasets, and accelerate
# - a pytorch focused implementations
# - deep dive on the fundamentals of training and interpreting loss and accuracy curves
# - fun interactive quizzes and certifications!
# 1,606
# 14 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 66,185 followers
# 5d
# Edited
# Report this post
# 🔥MODAL LABS DROPS $5,000💸
#
# ShallowCodeResearch just won
# Modal
# Labs' Choice Award - the BIGGEST single prize in our hackathon!
#
# 4200 Participants. 630 submissions. ONE $5K winner. This is it!🔥
#
# 🎯 App provides AI-assisted research and code gen. Integrates multiple agents to enhance your coding and research workflow.
#
# Try ShallowCodeResearch here:
# https://lnkd.in/g6rPF-fP
# 73
# 5 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel Vila Suero
# Building data tools @ Hugging Face 🤗
# 5d
# Edited
# Report this post
# ⚡ Open models mean you have more control. Now it also means lightning speed for real-time use cases.
# Groq
# 's speed is now available to all on
# Hugging Face
# to unlock 100s of use cases.
#
# If you want to get a sense of it, we've just enabled Groq as a provider in Sheets so you can test it with any Hub or local dataset!
# https://lnkd.in/dVu2f2SB
# Here's a demo translating reviews into French at lightning speed! (video is not accelerated)
#
# See all available models:
# https://lnkd.in/dxJdq8B6
# …more
# 31
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 66,185 followers
# 6d
# Edited
# Report this post
# 🏆 THE GRADIO AGENTS & MCP HACKATHON WINNERS ARE HERE! 🏆
#
# After reviewing 630+ incredible submissions, here are your winners!🎉 👇
# 🍾  TRACK WINNERS 🍾  🤑Cash Prizes: 🥇 $2,500 🥈 $500
#
# 🤖 MCP Server Track
# 🥇 Geo Calculator MCP:
# https://lnkd.in/gfkEJxKK
# 🥈 Documents MCP:
# https://lnkd.in/gaa4UytE
# 🎨 Custom Component Track
# 🥇 Gradio Workflow Builder:
# https://lnkd.in/gy3JY7hX
# 🥈 Chess MCP Server:
# https://lnkd.in/gCjRPzN7
# 🚀 Agentic App Track
# 🥇 LLM Game-Hub:
# https://lnkd.in/g96eKX3R
# 🥈 Sentinel One:
# https://lnkd.in/g5V3CmS7
# 🎁 SPECIAL AWARDS 🤑Cash Prizes: $500 each
#
# 👑 Community Choice Award: Consilium MCP
# https://lnkd.in/gK-w6sYA
# 🌟 Most Innovative Use of MCP Award: Modern Multiplayer Online Role-Playing Game  with MCP
# https://lnkd.in/grpTEm7w
# 🔥 The competition was very intense, and it went down to the wire for all the tracks and categories. We believe honorary mentions are due 🧡
#
# > Agent Track: 💪 Smart Customer Support Triage Agent --
# https://lnkd.in/gCHEpPKU
# > MCP Track: 🎵 Spotify MCP Tools --
# https://lnkd.in/gK_TexWF
# > Custom Component Track: 🎭 Consilium Roundtable Demo --
# https://lnkd.in/gcnQjjaF
# , &
# 🕵️ Agent Inspector --
# https://lnkd.in/gvcEBbV9
# We will be announcing the rest of the🎁 SPECIAL AWARDS 🎁 by our Sponsors
# Modal
# Labs
# Mistral AI
# ,
# LlamaIndex
# , and
# SambaNova Systems
# throughout this week. Stay tuned!  😀
# 423
# 29 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Perplexity
# Software Development
# San Francisco, California
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Google DeepMind
# Research Services
# London, London
# Cohere
# Software Development
# Toronto, Ontario
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Your California Privacy Choices
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app
#
#
#
# social media (Twitter)
# Webpage Title:
# No title found
# Webpage Contents:
# JavaScript is not available.
# We’ve detected that JavaScript is disabled in this browser. Please enable JavaScript or switch to a supported browser to continue using x.com. You can see a list of supported browsers in our Help Center.
# Help Center
# Terms of Service
# Privacy Policy
# Cookie Policy
# Imprint
# Ads info
# © 2025 X Corp.
# Something went wrong, but don’t fret — let’s give it another shot.
# Try again
# Some privacy related extensions may cause issues on x.com. Please disable them and try again.
#
#
#
# documentation page
# Webpage Title:
# Hugging Face - Documentation
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Documentations
# Hub & Client Libraries
# Hub
# Host Git-based models, datasets, and Spaces on the HF Hub
# Hub Python Library
# Python client to interact with the Hugging Face Hub
# Huggingface.js
# JavaScript libraries for Hugging Face with built-in TS types
# Tasks
# Explore demos, models, and datasets for any ML tasks
# Dataset viewer
# API for metadata, stats, and content of HF Hub datasets
# Deployment & Inference
# Inference Providers
# Call 200k+ models hosted by our 10+ Inference partners
# Inference Endpoints (dedicated)
# Deploy models on dedicated & fully managed infrastructure on HF
# Amazon SageMaker
# Train/deploy Transformers models with SageMaker/HF DLCs
# Text Generation Inference
# Serve language models with TGI optimized toolkit
# Text Embeddings Inference
# Serve embeddings models with TEI optimized toolkit
# Core ML Libraries
# Transformers
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# State-of-the-art Diffusion models in PyTorch
# Datasets
# Access & share datasets for any ML tasks
# Transformers.js
# State-of-the-art ML running directly in your browser
# Tokenizers
# Fast tokenizers optimized for research & production
# Evaluate
# Evaluate and compare models performance
# timm
# State-of-the-art vision models: layers, optimizers, and utilities
# Sentence Transformers
# Embeddings, Retrieval, and Reranking
# Training & Optimization
# PEFT
# Parameter-efficient finetuning for large language models
# Accelerate
# Train PyTorch models with multi-GPU, TPU, mixed precision
# Optimum
# Optimize HF Transformers for faster training/inference
# AWS Trainium & Inferentia
# Train/deploy Transformers/Diffusers on AWS
# TRL
# Train transformers LMs with reinforcement learning
# Safetensors
# Safe way to store/distribute neural network weights
# Bitsandbytes
# Optimize and quantize models with bitsandbytes
# Lighteval
# All-in-one toolkit to evaluate LLMs across multiple backends
# Collaboration & Extras
# Gradio
# Build ML demos and web apps with a few lines of Python
# smolagents
# Smol library to build great agents in Python
# LeRobot
# Making AI for Robotics more accessible with end-to-end learning
# AutoTrain
# AutoTrain API and UI for seamless model training
# Chat UI
# Open source chat frontend powering HuggingChat
# Leaderboards
# Create custom Leaderboards on Hugging Face
# Argilla
# Collaboration tool for building high-quality datasets
# Distilabel
# Framework for synthetic data generation and AI feedback
# Community
# Blog
# Learn
# Discord
# Forum
# Github
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs

# %%
#system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
#and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
#Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'models page', 'url': 'https://huggingface.co/models'}, {'type': 'datasets page', 'url': 'https://huggingface.co/datasets'}, {'type': 'spaces page', 'url': 'https://huggingface.co/spaces'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}, {'type': 'community discussion page', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nCommunity\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\nnanonets/Nanonets-OCR-s\nUpdated\n3 days ago\n•\n177k\n•\n1.07k\nMiniMaxAI/MiniMax-M1-80k\nUpdated\n5 days ago\n•\n10.4k\n•\n523\nMenlo/Jan-nano\nUpdated\n6 days ago\n•\n29.1k\n•\n372\ngoogle/magenta-realtime\nUpdated\nabout 15 hours ago\n•\n225\nmoonshotai/Kimi-Dev-72B\nUpdated\n7 days ago\n•\n9.72k\n•\n260\nBrowse 1M+ models\nSpaces\nRunning\n714\n714\nSparc3D\n🏃\nNext-Gen High-Resolution 3D Model Generation\nRunning\n8.51k\n8.51k\nDeepSite v2\n🐳\nGenerate any application with DeepSeek\nRunning\non\nZero\n411\n411\nHunyuan3D-2.1\n👻\nImage-to-3D Generation\nRunning\n251\n251\nMiniMax M1\n💬\nGenerate code from text prompts\nRunning\non\nZero\n194\n194\nPartPacker\n🪴\nPart-level image-to-3D generation.\nBrowse 400k+ applications\nDatasets\nEssentialAI/essential-web-v1.0\nUpdated\n1 day ago\n•\n75.5k\n•\n137\ninstitutional/institutional-books-1.0\nUpdated\n7 days ago\n•\n38.2k\n•\n164\nfka/awesome-chatgpt-prompts\nUpdated\nJan 6\n•\n22.9k\n•\n8.01k\nnvidia/AceReason-1.1-SFT\nUpdated\n5 days ago\n•\n2.95k\n•\n32\nnvidia/Nemotron-Personas\nUpdated\n14 days ago\n•\n18.5k\n•\n142\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n766 models\n•\n3.48k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.17k models\n•\n6.57k followers\nAmazon\ncompany\n•\n20 models\n•\n3.25k followers\nGoogle\ncompany\n•\n1k models\n•\n17.2k followers\nIntel\ncompany\n•\n234 models\n•\n2.66k followers\nMicrosoft\ncompany\n•\n393 models\n•\n13.1k followers\nGrammarly\nEnterprise\ncompany\n•\n10 models\n•\n165 followers\nWriter\nEnterprise\ncompany\n•\n21 models\n•\n298 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n145,980\nState-of-the-art ML for PyTorch, TensorFlow, JAX\nDiffusers\n29,458\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,319\nSafe way to store/distribute neural network weights\nHub Python Library\n2,707\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,828\nFast tokenizers optimized for research & production\nTRL\n14,301\nTrain transformers LMs with reinforcement learning\nTransformers.js\n13,877\nState-of-the-art ML running directly in your browser\nsmolagents\n20,475\nSmol library to build great agents in Python\nPEFT\n18,837\nParameter-efficient finetuning for large language models\nDatasets\n20,290\nAccess & share datasets for any ML tasks\nText Generation Inference\n10,246\nServe language models with TGI o ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}]}
# # Welcome to HuggingFace: Where AI Gets a Hug! 🤗
#
# ## The AI Community Building the Future
#
# At HuggingFace, we don't just embrace the future; we hug it! Join our diverse team of AI enthusiasts, models, datasets, and applications as we tackle the ultimate goal: Making Artificial Intelligence friendly and accessible for everyone!
#
# ---
#
# ### 🚀 What We Do
#
# - **Models Galore**: With **1M+ models** at your fingertips, we have more models than you have socks. And trust us, that’s a lot.
# - **Dataset Delight**: Choose from **250k+ datasets!** Because sometimes you need to train an AI to understand the difference between a cat and a loaf of bread.
# - **AI Apps**: Explore cutting-edge applications that will make you wonder how we got here. Discover our AI apps or just admire them like fine art.
#
# ---
#
# ### ❤️ Our Amazing Customers
#
# Over **50,000 organizations** (yes, you read that right!) use HuggingFace. From the tech behemoths like Google and Amazon to non-profits wanting to change the world, we cater to everyone! A few of our biggest fans include:
# - **Microsoft**
# - **Meta**
# - **Grammarly**
#
# Think of us as the friendly neighborhood AI toolkit, but instead of chasing villains, we're collaborating on mind-blowing models and datasets.
#
# ---
#
# ### 🎉 Company Culture
#
# At HuggingFace, our spirit animal is an AI assistant who loves team-building exercises. We prioritize collaboration, creativity, and having a great time while doing amazing work.
#
# - **Open Source Fun**: We believe in an **open-source** environment. So, if you have a great idea, unleash it!
# - **Flexible Work Culture**: Who needs shoes when you can work in your pajama pants? Our working conditions prioritize comfort, creativity, and commitment to innovation.
#
# ---
#
# ### 💼 Careers With Us
#
# Are you ready to embark on a journey to create the future of AI? Join our team and enjoy:
# - **Awesome Colleagues**: Work alongside the crème de la crème of AI experts who will challenge and inspire you daily.
# - **Hybrid Work Model**: Work remotely or at our vibrant office! Just don’t forget to bring your love for all things AI.
# - **Careers that Evolve**: Like a fine wine or a well-trainined AI model, we all improve with time.
#
# ---
#
# ### 🤔 Still Unsure?
#
# Check out our thriving **community**, hit us up on **Twitter**, or dive deep into our extensive **docs** to find out why HuggingFace might just be the best decision you’ve ever made!
#
# Join us and let’s give the future a big warm hug! 🌍❤️
#
# ---
#
# ### Sign Up Today!
#
# Don’t miss out on this exciting opportunity! [Sign Up](#) and let’s start building a friendly world with AI together!
#
# ---
#
# **HuggingFace - From Models to Friends, we’re redefining AI!**

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'docs page', 'url': 'https://huggingface.co/docs'}]}
# # 🤗 Hugging Face: The Warmest AI Company on Earth! 🤗
#
# ---
#
# **Where We’re Going, We Don’t Need Roads… Just Lots of Data!**
#
# At Hugging Face, we believe we’re not just building AI; we’re building a community – a family of creative geniuses equipped with machine learning models, datasets, and a whole lot of enthusiasm… and perhaps some coffee (or a lot).
#
# ---
#
# ## 🌟 Why Hugging Face?
#
# - **1 Million Models**: Yep, you read that right! With over 1M models, your AI dreams are just a click away. From text generation to image recognition, we've got your back!
#
# - **300K Applications**: No more “app-lifting” here! We’ve got all your favorite AI apps, without a subscription to world domination.
#
# - **Spaces About to Get Cozy**: Our virtual Spaces let you collaborate on data like it’s a group project in college – minus the last-minute panic!
#
# ---
#
# ## 🌍 Our Culture: Kindness Meets Code
#
# When you step into the Hugging Face family, get ready for high-fives, innovation demos, and the occasional spontaneous dance party in the office. Here’s what you can expect:
#
# - **Collaboration Like Never Before**: We believe in sharing knowledge and high-fives! Jokes aside, our community thrives on collaboration and open-source spirit.
#
# - **Diverse & Inclusive**: You don’t need to score 100 on a coding exam to join us. Just bring your curious mind and a love for AI!
#
# - **A Healthy Work-Life Balance**: We embrace the “work hard, play harder” philosophy – with plenty of coffee breaks and creative brainstorming sessions.
#
# ---
#
# ## 🛠️ Who’s in Our Tech Toolkit?
#
# - **Transformers**: Our superhero models that understand languages better than most humans!
# - **Diffusers**: No, not the ones for essential oils. We’re talking about state-of-the-art models that diffuse complex tasks into user-friendly formats.
# - **Tokenizers**: Because every word matters!
#
# ---
#
# ## 🎉 Join Us!
#
# Want to hang with the coolest AI community around? Whether you're an investor, job seeker, or customer, there’s a seat at our virtual coffee table for you!
#
# - **Careers**: We’re hiring! If you can keep up with our caffeine and coding pace, apply now!
#
# - **Customers**: Over 50,000 organizations trust us, including names like Google, Amazon, and even your friendly neighborhood almighty software companies.
#
# - **Investors**: Tap into the AI goldmine! Join us as we explore the depths of artificial intelligence together.
#
# ---
#
# ## 🤖 What Our Customers Are Saying:
#
# - “Hugging Face made AI feel like a warm hug!” – - Random Enthusiast
# - “The community is so supportive, I learned more in a week than my entire college experience!” – - Anonymous
#
# ---
#
# **🚀 So What Are You Waiting For?**
#
# Join the AI revolution that believes in community, kindness, and loads of data. Whether you want to build the next great model, collaborate on projects, or contribute to our mission, at Hugging Face, we say:
#
# **"Hugs of Knowledge Await!"**
#
# ---
#
# [**Join Us!**](https://huggingface.co/join)👈
#
# Hugging Face - The AI community building the future… one giggle at a time!

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
